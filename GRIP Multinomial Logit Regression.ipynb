# %% [markdown]
# # Multinomial Logit — **Same preprocessing as OLS**, modelling step swapped
# This notebook mirrors the OLS pipeline (winsorisation, standardisation, dummies, interaction),
# then fits a multinomial logit on `SGrowth_2`. It auto-detects the base category and derives
# `High Growth vs Stressed` if needed. Exports odds ratios and marginal effects to Excel.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats.mstats import winsorize
from IPython.display import display
import warnings

# %%
# === LOAD DATA ===
FILE = 'Results/GRIP Analysis FILTER.xlsx'
df = pd.read_excel(FILE)
print('Loaded:', df.shape)
# Out:
# Loaded: (9050, 81)

# %%
# === PARAMETERS (match OLS) ===
target_cont = 'LSGrowth_2023_2019'                 # continuous growth used in OLS
winsor_limits = (0.025, 0.025)                     # 2.5% tails as in OLS
core_cont = ['Starting_INT','Starting_BS_Strength','Starting_Size_ln','Starting_Profit']
cat_target = 'SGrowth_2'                           # categorical for MNLogit
sector_ref = 'budownictwo'                         # OLS reference sector
pf_col = 'P/F'                                     # ownership P/F
hgx_col = 'HGX'                                    # Increased/Decreased Export Intensity

# %%
# === WINSORISE CONTINUOUS DV (as in OLS) ===
if target_cont in df.columns:
    arr = df[target_cont].astype(float).to_numpy()
    df[target_cont + '_win'] = winsorize(arr, limits=winsor_limits)
    print('Winsorised DV created:', target_cont + '_win')
else:
    print('Warning: continuous OLS DV not found; continuing with multinomial anyway.')
# Out:
# Winsorised DV created: LSGrowth_2023_2019_win

# %%
# === STANDARDISE core continuous predictors (z-score), as in OLS ===
for c in core_cont:
    if c in df.columns:
        mu, sd = df[c].mean(), df[c].std(ddof=0)
        df[c + '_z'] = (df[c] - mu) / (sd if sd else 1.0)
    else:
        raise KeyError(f'Missing predictor: {c}')
print('Standardised predictors:', [c + '_z' for c in core_cont])
# Out:
# Standardised predictors: ['Starting_INT_z', 'Starting_BS_Strength_z', 'Starting_Size_ln_z', 'Starting_Profit_z']

# %%
# === DUMMIES to match OLS ===
# Foreign dummy from P/F (F=1, P=0)
df['Foreign'] = (df[pf_col].astype(str).str.upper().str.strip() == 'F').astype(int)

# HGX Increased Export Intensity dummy (reference = Decreased)
df['HGX_Increased Export Intensity'] = (df[hgx_col].astype(str).str.strip() == 'Increased Export Intensity').astype(int)

# Sector dummies, drop reference sector
sector_d = pd.get_dummies(df['Sector'], prefix='Sector', drop_first=False)
ref_col = f'Sector_{sector_ref}'
if ref_col in sector_d.columns:
    sector_d = sector_d.drop(columns=[ref_col])
print('Sector dummies:', len(sector_d.columns), ' (ref =', sector_ref, ')')
# Out:
# Sector dummies: 13  (ref = budownictwo )

# %%
# === INTERACTION (as in OLS) ===
df['Starting_INT_Mult_Starting_Size_ln'] = df['Starting_INT'] * df['Starting_Size_ln']

# Collect the design matrix columns mirroring OLS structure (z-scored cores + dummies + interaction)
X_cols = [c + '_z' for c in core_cont] + ['Foreign','HGX_Increased Export Intensity','Starting_INT_Mult_Starting_Size_ln']
X = pd.concat([df[X_cols], sector_d], axis=1)

# Align with categorical target
cat_map = {'0.Stressed':0,'1.Declining':1,'2.Stable':2,'3.High Growth':3}
y = df[cat_target].map(cat_map)
mask = (~y.isna()) & (~X.isna().any(axis=1))
X = X.loc[mask].copy()
y = y.loc[mask].astype(int)
print('Model N:', X.shape[0], 'Features:', X.shape[1])
# Out:
# Model N: 9015 Features: 20

# %%
# === SAFETY: ensure numeric dtypes to avoid object errors ===
Xc = sm.add_constant(X, has_constant='add')
Xc = Xc.astype(float)
y = y.astype(int)
print('dtypes:', Xc.dtypes.value_counts().to_dict())
# Out:
# dtypes: {dtype('float64'): 21}

# %%
# === Minimal Multinomial Logit: clean, quiet, results only ===
# Inputs: X (DataFrame of predictors), y (Series/array of integer labels)

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# 1) Prepare design matrix
Xc = sm.add_constant(X, has_constant='add').astype(float)
y  = pd.Series(y).astype(int)

# Drop zero-variance predictors except intercept
dropcols = [c for c in Xc.columns if c != 'const' and Xc[c].nunique(dropna=True) <= 1]
if dropcols:
    Xc = Xc.drop(columns=dropcols)

# Standardize non-intercept columns
cols = [c for c in Xc.columns if c != 'const']
Xc[cols] = (Xc[cols] - Xc[cols].mean()) / Xc[cols].std(ddof=0)

mnl = sm.MNLogit(y, Xc)

#2) Try unregularized fit first
try:
    res = mnl.fit(method="lbfgs", maxiter=2000, disp=False, cov_type="HC1")
except (TypeError, np.linalg.LinAlgError):
    res = mnl.fit(method="lbfgs", maxiter=2000, disp=False)

# 3) If not converged, apply gentle ridge and refit for SEs
if not bool(res.mle_retvals.get("converged", True)):
    res_reg = mnl.fit_regularized(method="lbfgs", alpha=0.5, L1_wt=0.0, maxiter=4000, disp=False)
    start = np.asarray(res_reg.params).ravel()
    try:
        res = mnl.fit(method="lbfgs", start_params=start, maxiter=4000, disp=False, cov_type="HC1")
    except TypeError:
        res = mnl.fit(method="lbfgs", start_params=start, maxiter=4000, disp=False)

# 4) Display results only
try:
    display(res.summary())      # or display(res.summary2()) for a wider table
except Exception:
    print(res.summary())
print(res.params.index)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              SGrowth_2   No. Observations:                 9015
# Model:                        MNLogit   Df Residuals:                     8952
# Method:                           MLE   Df Model:                           60
# Date:                Thu, 30 Oct 2025   Pseudo R-squ.:                 0.04743
# Time:                        20:49:44   Log-Likelihood:                -10655.
# converged:                       True   LL-Null:                       -11185.
# Covariance Type:                  HC1   LLR p-value:                4.960e-183
# ======================================================================================================
#                        SGrowth_2=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.1450      0.039     29.371      0.000       1.069       1.221
# Starting_INT_z                         0.2993      0.569      0.526      0.599      -0.816       1.414
# Starting_BS_Strength_z                 0.2932      0.045      6.453      0.000       0.204       0.382
# Starting_Size_ln_z                     0.1470      0.049      2.969      0.003       0.050       0.244
# Starting_Profit_z                      0.1077      0.052      2.074      0.038       0.006       0.209
# Foreign                               -0.0220      0.037     -0.601      0.548      -0.094       0.050
# HGX_Increased Export Intensity         0.0190      0.035      0.541      0.588      -0.050       0.088
# Starting_INT_Mult_Starting_Size_ln    -0.3499      0.572     -0.611      0.541      -1.472       0.772
# Sector_chemia                          0.0845      0.038      2.244      0.025       0.011       0.158
# Sector_energetyka                     -0.0954      0.046     -2.079      0.038      -0.185      -0.005
# Sector_górnictwo i hutnictwo           0.1084      0.037      2.957      0.003       0.037       0.180
# Sector_handel detaliczny               0.0821      0.038      2.157      0.031       0.007       0.157
# Sector_handel hurtowy                  0.0166      0.040      0.416      0.677      -0.062       0.095
# Sector_media, telekomunkacja, IT       0.2625      0.042      6.269      0.000       0.180       0.345
# Sector_motoryzacja                     0.2468      0.044      5.605      0.000       0.160       0.333
# Sector_ochrona zdrowia i farmacja      0.1942      0.041      4.693      0.000       0.113       0.275
# Sector_paliwa                         -0.0467      0.034     -1.373      0.170      -0.113       0.020
# Sector_produkcja                       0.2380      0.049      4.904      0.000       0.143       0.333
# Sector_transport                       0.1858      0.042      4.453      0.000       0.104       0.268
# Sector_usługi                          0.2109      0.040      5.279      0.000       0.133       0.289
# Sector_żywność                         0.5648      0.066      8.613      0.000       0.436       0.693
# ------------------------------------------------------------------------------------------------------
#                        SGrowth_2=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.1909      0.039     30.639      0.000       1.115       1.267
# Starting_INT_z                         1.8425      0.563      3.270      0.001       0.738       2.947
# Starting_BS_Strength_z                 0.3288      0.043      7.635      0.000       0.244       0.413
# Starting_Size_ln_z                     0.3066      0.047      6.520      0.000       0.214       0.399
# Starting_Profit_z                      0.1986      0.055      3.624      0.000       0.091       0.306
# Foreign                               -0.1088      0.037     -2.952      0.003      -0.181      -0.037
# HGX_Increased Export Intensity         0.1370      0.035      3.908      0.000       0.068       0.206
# Starting_INT_Mult_Starting_Size_ln    -2.0122      0.567     -3.551      0.000      -3.123      -0.902
# Sector_chemia                          0.0950      0.036      2.604      0.009       0.023       0.166
# Sector_energetyka                     -0.1523      0.047     -3.260      0.001      -0.244      -0.061
# Sector_górnictwo i hutnictwo           0.0561      0.037      1.534      0.125      -0.016       0.128
# Sector_handel detaliczny              -0.0034      0.039     -0.087      0.931      -0.079       0.072
# Sector_handel hurtowy                  0.0065      0.038      0.169      0.866      -0.069       0.082
# Sector_media, telekomunkacja, IT       0.0902      0.043      2.084      0.037       0.005       0.175
# Sector_motoryzacja                     0.1450      0.044      3.288      0.001       0.059       0.231
# Sector_ochrona zdrowia i farmacja      0.1534      0.041      3.750      0.000       0.073       0.234
# Sector_paliwa                         -0.0852      0.033     -2.563      0.010      -0.150      -0.020
# Sector_produkcja                       0.0946      0.048      1.970      0.049       0.000       0.189
# Sector_transport                       0.1914      0.041      4.706      0.000       0.112       0.271
# Sector_usługi                          0.0911      0.040      2.265      0.023       0.012       0.170
# Sector_żywność                         0.6583      0.064     10.224      0.000       0.532       0.785
# ------------------------------------------------------------------------------------------------------
#                        SGrowth_2=3       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.3932      0.050     -7.846      0.000      -0.491      -0.295
# Starting_INT_z                         3.7230      0.840      4.434      0.000       2.077       5.369
# Starting_BS_Strength_z                 0.0676      0.048      1.423      0.155      -0.026       0.161
# Starting_Size_ln_z                     0.2948      0.057      5.174      0.000       0.183       0.406
# Starting_Profit_z                      0.1820      0.059      3.089      0.002       0.067       0.297
# Foreign                               -0.2572      0.048     -5.322      0.000      -0.352      -0.162
# HGX_Increased Export Intensity         0.1578      0.045      3.480      0.001       0.069       0.247
# Starting_INT_Mult_Starting_Size_ln    -3.7679      0.848     -4.444      0.000      -5.430      -2.106
# Sector_chemia                         -0.0985      0.067     -1.481      0.139      -0.229       0.032
# Sector_energetyka                      0.2661      0.038      6.956      0.000       0.191       0.341
# Sector_górnictwo i hutnictwo          -1.2633      0.037    -34.585      0.000      -1.335      -1.192
# Sector_handel detaliczny               0.1086      0.047      2.310      0.021       0.016       0.201
# Sector_handel hurtowy                  0.0695      0.054      1.280      0.201      -0.037       0.176
# Sector_media, telekomunkacja, IT       0.2387      0.053      4.500      0.000       0.135       0.343
# Sector_motoryzacja                     0.2316      0.060      3.869      0.000       0.114       0.349
# Sector_ochrona zdrowia i farmacja      0.1768      0.054      3.264      0.001       0.071       0.283
# Sector_paliwa                          0.0724      0.041      1.757      0.079      -0.008       0.153
# Sector_produkcja                       0.0959      0.070      1.378      0.168      -0.041       0.232
# Sector_transport                       0.0910      0.058      1.568      0.117      -0.023       0.205
# Sector_usługi                          0.2418      0.050      4.847      0.000       0.144       0.340
# Sector_żywność                         0.6275      0.076      8.264      0.000       0.479       0.776
# ======================================================================================================
# """
# Index(['const', 'Starting_INT_z', 'Starting_BS_Strength_z',
#        'Starting_Size_ln_z', 'Starting_Profit_z', 'Foreign',
#        'HGX_Increased Export Intensity', 'Starting_INT_Mult_Starting_Size_ln',
#        'Sector_chemia', 'Sector_energetyka', 'Sector_górnictwo i hutnictwo',
#        'Sector_handel detaliczny', 'Sector_handel hurtowy',
#        'Sector_media, telekomunkacja, IT', 'Sector_motoryzacja',
#        'Sector_ochrona zdrowia i farmacja', 'Sector_paliwa',
#        'Sector_produkcja', 'Sector_transport', 'Sector_usługi',
#        'Sector_żywność'],
#       dtype='object')

# %%
# === MARGINAL EFFECTS (average dydx) ===

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

mfx = res.get_margeff(at='overall', method='dydx').summary_frame()

# display the whole thing
display(mfx)

mfx.to_excel("Results/Regression MNL Marginal Effects.xlsx", index=True)
# Out:
#                                                    dy/dx  Std. Err.  \
# endog       exog
# SGrowth_2=0 Starting_INT_z                     -0.157405   0.058554
#             Starting_BS_Strength_z             -0.031356   0.004531
#             Starting_Size_ln_z                 -0.026328   0.004983
#             Starting_Profit_z                  -0.017541   0.005647
#             Foreign                             0.010042   0.003797
#             HGX_Increased Export Intensity     -0.009840   0.003639
#             Starting_INT_Mult_Starting_Size_ln  0.168766   0.058949
#             Sector_chemia                      -0.007354   0.003886
#             Sector_energetyka                   0.008269   0.004256
#             Sector_górnictwo i hutnictwo        0.010049   0.003873
#             Sector_handel detaliczny           -0.005440   0.003899
#             Sector_handel hurtowy              -0.002130   0.003919
#             Sector_media, telekomunkacja, IT   -0.020732   0.004396
#             Sector_motoryzacja                 -0.022511   0.004467
#             Sector_ochrona zdrowia i farmacja  -0.019540   0.004296
#             Sector_paliwa                       0.005391   0.003272
#             Sector_produkcja                   -0.017690   0.004911
#             Sector_transport                   -0.019738   0.004281
#             Sector_usługi                      -0.018277   0.004114
#             Sector_żywność                     -0.068736   0.007061
# SGrowth_2=1 Starting_INT_z                     -0.325030   0.087522
#             Starting_BS_Strength_z              0.017283   0.006308
#             Starting_Size_ln_z                 -0.020688   0.007360
#             Starting_Profit_z                  -0.010258   0.006181
#             Foreign                             0.019518   0.005336
#             HGX_Increased Export Intensity     -0.020730   0.005062
#             Starting_INT_Mult_Starting_Size_ln  0.339322   0.087801
#             Sector_chemia                       0.009083   0.005807
#             Sector_energetyka                  -0.009250   0.008886
#             Sector_górnictwo i hutnictwo        0.060832   0.005131
#             Sector_handel detaliczny            0.015294   0.005860
#             Sector_handel hurtowy               0.000410   0.006836
#             Sector_media, telekomunkacja, IT    0.038317   0.005877
#             Sector_motoryzacja                  0.027203   0.007049
#             Sector_ochrona zdrowia i farmacja   0.015995   0.005808
#             Sector_paliwa                      -0.000977   0.006075
#             Sector_produkcja                    0.037147   0.007817
#             Sector_transport                    0.011683   0.006075
#             Sector_usługi                       0.026386   0.005884
#             Sector_żywność                      0.012329   0.007219
# SGrowth_2=2 Starting_INT_z                      0.238755   0.086494
#             Starting_BS_Strength_z              0.030790   0.005756
#             Starting_Size_ln_z                  0.038057   0.006809
#             Starting_Profit_z                   0.023214   0.006351
#             Foreign                            -0.012082   0.005440
#             HGX_Increased Export Intensity      0.022673   0.005058
#             Starting_INT_Mult_Starting_Size_ln -0.268636   0.086735
#             Sector_chemia                       0.013338   0.005589
#             Sector_energetyka                  -0.031162   0.009055
#             Sector_górnictwo i hutnictwo        0.044670   0.005142
#             Sector_handel detaliczny           -0.016534   0.005984
#             Sector_handel hurtowy              -0.003491   0.006541
#             Sector_media, telekomunkacja, IT   -0.025733   0.006228
#             Sector_motoryzacja                 -0.010728   0.007106
#             Sector_ochrona zdrowia i farmacja   0.000740   0.005726
#             Sector_paliwa                      -0.015520   0.005955
#             Sector_produkcja                   -0.015909   0.007767
#             Sector_transport                    0.013831   0.005845
#             Sector_usługi                      -0.018304   0.006006
#             Sector_żywność                      0.046376   0.006785
# SGrowth_2=3 Starting_INT_z                      0.243679   0.061481
#             Starting_BS_Strength_z             -0.016717   0.003135
#             Starting_Size_ln_z                  0.008959   0.003648
#             Starting_Profit_z                   0.004585   0.003334
#             Foreign                            -0.017479   0.003351
#             HGX_Increased Export Intensity      0.007897   0.003092
#             Starting_INT_Mult_Starting_Size_ln -0.239452   0.062122
#             Sector_chemia                      -0.015067   0.005189
#             Sector_energetyka                   0.032143   0.002316
#             Sector_górnictwo i hutnictwo       -0.115551   0.003974
#             Sector_handel detaliczny            0.006679   0.003257
#             Sector_handel hurtowy               0.005211   0.004052
#             Sector_media, telekomunkacja, IT    0.008148   0.003561
#             Sector_motoryzacja                  0.006036   0.004329
#             Sector_ochrona zdrowia i farmacja   0.002806   0.003693
#             Sector_paliwa                       0.011107   0.003066
#             Sector_produkcja                   -0.003548   0.005151
#             Sector_transport                   -0.005775   0.004161
#             Sector_usługi                       0.010195   0.003398
#             Sector_żywność                      0.010032   0.004134
#
#                                                         z       Pr(>|z|)  \
# endog       exog
# SGrowth_2=0 Starting_INT_z                      -2.688189   7.184066e-03
#             Starting_BS_Strength_z              -6.920683   4.494716e-12
#             Starting_Size_ln_z                  -5.283218   1.269344e-07
#             Starting_Profit_z                   -3.106213   1.894999e-03
#             Foreign                              2.644576   8.179326e-03
#             HGX_Increased Export Intensity      -2.703819   6.854765e-03
#             Starting_INT_Mult_Starting_Size_ln   2.862918   4.197595e-03
#             Sector_chemia                       -1.892375   5.844107e-02
#             Sector_energetyka                    1.942793   5.204118e-02
#             Sector_górnictwo i hutnictwo         2.594856   9.463064e-03
#             Sector_handel detaliczny            -1.395288   1.629291e-01
#             Sector_handel hurtowy               -0.543418   5.868423e-01
#             Sector_media, telekomunkacja, IT    -4.716134   2.403677e-06
#             Sector_motoryzacja                  -5.038935   4.681288e-07
#             Sector_ochrona zdrowia i farmacja   -4.548955   5.391287e-06
#             Sector_paliwa                        1.647694   9.941540e-02
#             Sector_produkcja                    -3.601854   3.159553e-04
#             Sector_transport                    -4.610517   4.016687e-06
#             Sector_usługi                       -4.442677   8.884660e-06
#             Sector_żywność                      -9.734481   2.149111e-22
# SGrowth_2=1 Starting_INT_z                      -3.713679   2.042675e-04
#             Starting_BS_Strength_z               2.739966   6.144554e-03
#             Starting_Size_ln_z                  -2.810790   4.942006e-03
#             Starting_Profit_z                   -1.659463   9.702255e-02
#             Foreign                              3.658125   2.540672e-04
#             HGX_Increased Export Intensity      -4.095268   4.216801e-05
#             Starting_INT_Mult_Starting_Size_ln   3.864667   1.112408e-04
#             Sector_chemia                        1.564142   1.177842e-01
#             Sector_energetyka                   -1.040965   2.978919e-01
#             Sector_górnictwo i hutnictwo        11.854843   2.031038e-32
#             Sector_handel detaliczny             2.610089   9.051880e-03
#             Sector_handel hurtowy                0.059953   9.521930e-01
#             Sector_media, telekomunkacja, IT     6.519435   7.057281e-11
#             Sector_motoryzacja                   3.858983   1.138598e-04
#             Sector_ochrona zdrowia i farmacja    2.753958   5.887927e-03
#             Sector_paliwa                       -0.160886   8.721832e-01
#             Sector_produkcja                     4.751872   2.015421e-06
#             Sector_transport                     1.923105   5.446682e-02
#             Sector_usługi                        4.484022   7.324902e-06
#             Sector_żywność                       1.707918   8.765158e-02
# SGrowth_2=2 Starting_INT_z                       2.760356   5.773844e-03
#             Starting_BS_Strength_z               5.349566   8.816562e-08
#             Starting_Size_ln_z                   5.589017   2.283593e-08
#             Starting_Profit_z                    3.655181   2.570006e-04
#             Foreign                             -2.221167   2.633967e-02
#             HGX_Increased Export Intensity       4.482314   7.383797e-06
#             Starting_INT_Mult_Starting_Size_ln  -3.097209   1.953520e-03
#             Sector_chemia                        2.386414   1.701359e-02
#             Sector_energetyka                   -3.441506   5.784852e-04
#             Sector_górnictwo i hutnictwo         8.686826   3.727064e-18
#             Sector_handel detaliczny            -2.762898   5.729060e-03
#             Sector_handel hurtowy               -0.533622   5.936033e-01
#             Sector_media, telekomunkacja, IT    -4.131907   3.597660e-05
#             Sector_motoryzacja                  -1.509803   1.310936e-01
#             Sector_ochrona zdrowia i farmacja    0.129179   8.972163e-01
#             Sector_paliwa                       -2.606422   9.149375e-03
#             Sector_produkcja                    -2.048356   4.052518e-02
#             Sector_transport                     2.366243   1.796967e-02
#             Sector_usługi                       -3.047390   2.308383e-03
#             Sector_żywność                       6.835214   8.188283e-12
# SGrowth_2=3 Starting_INT_z                       3.963490   7.386191e-05
#             Starting_BS_Strength_z              -5.332476   9.688278e-08
#             Starting_Size_ln_z                   2.456200   1.404152e-02
#             Starting_Profit_z                    1.375131   1.690910e-01
#             Foreign                             -5.216515   1.823207e-07
#             HGX_Increased Export Intensity       2.554031   1.064839e-02
#             Starting_INT_Mult_Starting_Size_ln  -3.854571   1.159329e-04
#             Sector_chemia                       -2.903428   3.691013e-03
#             Sector_energetyka                   13.875804   8.879193e-44
#             Sector_górnictwo i hutnictwo       -29.073662  7.730072e-186
#             Sector_handel detaliczny             2.050863   4.028030e-02
#             Sector_handel hurtowy                1.285769   1.985239e-01
#             Sector_media, telekomunkacja, IT     2.288025   2.213607e-02
#             Sector_motoryzacja                   1.394413   1.631929e-01
#             Sector_ochrona zdrowia i farmacja    0.759824   4.473597e-01
#             Sector_paliwa                        3.623148   2.910390e-04
#             Sector_produkcja                    -0.688788   4.909567e-01
#             Sector_transport                    -1.387831   1.651886e-01
#             Sector_usługi                        2.999999   2.699809e-03
#             Sector_żywność                       2.426427   1.524830e-02
#
#                                                 Conf. Int. Low  Cont. Int. Hi.
# endog       exog
# SGrowth_2=0 Starting_INT_z                           -0.272168       -0.042641
#             Starting_BS_Strength_z                   -0.040237       -0.022476
#             Starting_Size_ln_z                       -0.036096       -0.016561
#             Starting_Profit_z                        -0.028609       -0.006473
#             Foreign                                   0.002600        0.017485
#             HGX_Increased Export Intensity           -0.016973       -0.002707
#             Starting_INT_Mult_Starting_Size_ln        0.053228        0.284304
#             Sector_chemia                            -0.014971        0.000263
#             Sector_energetyka                        -0.000073        0.016610
#             Sector_górnictwo i hutnictwo              0.002459        0.017639
#             Sector_handel detaliczny                 -0.013082        0.002202
#             Sector_handel hurtowy                    -0.009812        0.005552
#             Sector_media, telekomunkacja, IT         -0.029348       -0.012116
#             Sector_motoryzacja                       -0.031266       -0.013755
#             Sector_ochrona zdrowia i farmacja        -0.027959       -0.011121
#             Sector_paliwa                            -0.001022        0.011804
#             Sector_produkcja                         -0.027317       -0.008064
#             Sector_transport                         -0.028129       -0.011347
#             Sector_usługi                            -0.026340       -0.010214
#             Sector_żywność                           -0.082576       -0.054897
# SGrowth_2=1 Starting_INT_z                           -0.496571       -0.153489
#             Starting_BS_Strength_z                    0.004920        0.029646
#             Starting_Size_ln_z                       -0.035113       -0.006262
#             Starting_Profit_z                        -0.022373        0.001857
#             Foreign                                   0.009061        0.029976
#             HGX_Increased Export Intensity           -0.030651       -0.010809
#             Starting_INT_Mult_Starting_Size_ln        0.167235        0.511409
#             Sector_chemia                            -0.002298        0.020464
#             Sector_energetyka                        -0.026667        0.008166
#             Sector_górnictwo i hutnictwo              0.050775        0.070889
#             Sector_handel detaliczny                  0.003810        0.026779
#             Sector_handel hurtowy                    -0.012989        0.013808
#             Sector_media, telekomunkacja, IT          0.026797        0.049836
#             Sector_motoryzacja                        0.013387        0.041020
#             Sector_ochrona zdrowia i farmacja         0.004611        0.027378
#             Sector_paliwa                            -0.012884        0.010929
#             Sector_produkcja                          0.021825        0.052469
#             Sector_transport                         -0.000224        0.023590
#             Sector_usługi                             0.014853        0.037919
#             Sector_żywność                           -0.001819        0.026477
# SGrowth_2=2 Starting_INT_z                            0.069229        0.408281
#             Starting_BS_Strength_z                    0.019510        0.042071
#             Starting_Size_ln_z                        0.024711        0.051403
#             Starting_Profit_z                         0.010766        0.035661
#             Foreign                                  -0.022743       -0.001421
#             HGX_Increased Export Intensity            0.012759        0.032587
#             Starting_INT_Mult_Starting_Size_ln       -0.438633       -0.098639
#             Sector_chemia                             0.002384        0.024293
#             Sector_energetyka                        -0.048908       -0.013415
#             Sector_górnictwo i hutnictwo              0.034592        0.054749
#             Sector_handel detaliczny                 -0.028262       -0.004805
#             Sector_handel hurtowy                    -0.016311        0.009330
#             Sector_media, telekomunkacja, IT         -0.037940       -0.013527
#             Sector_motoryzacja                       -0.024656        0.003199
#             Sector_ochrona zdrowia i farmacja        -0.010483        0.011963
#             Sector_paliwa                            -0.027191       -0.003849
#             Sector_produkcja                         -0.031132       -0.000687
#             Sector_transport                          0.002375        0.025287
#             Sector_usługi                            -0.030076       -0.006532
#             Sector_żywność                            0.033078        0.059674
# SGrowth_2=3 Starting_INT_z                            0.123179        0.364180
#             Starting_BS_Strength_z                   -0.022861       -0.010573
#             Starting_Size_ln_z                        0.001810        0.016108
#             Starting_Profit_z                        -0.001950        0.011119
#             Foreign                                  -0.024046       -0.010911
#             HGX_Increased Export Intensity            0.001837        0.013957
#             Starting_INT_Mult_Starting_Size_ln       -0.361208       -0.117696
#             Sector_chemia                            -0.025238       -0.004896
#             Sector_energetyka                         0.027603        0.036683
#             Sector_górnictwo i hutnictwo             -0.123341       -0.107761
#             Sector_handel detaliczny                  0.000296        0.013063
#             Sector_handel hurtowy                    -0.002732        0.013153
#             Sector_media, telekomunkacja, IT          0.001168        0.015129
#             Sector_motoryzacja                       -0.002448        0.014519
#             Sector_ochrona zdrowia i farmacja        -0.004432        0.010043
#             Sector_paliwa                             0.005099        0.017115
#             Sector_produkcja                         -0.013643        0.006547
#             Sector_transport                         -0.013931        0.002381
#             Sector_usługi                             0.003534        0.016856
#             Sector_żywność                            0.001929        0.018135

# %%
# === Export MNLogit coefficients with correct outcome labels (matches summary) ===
import pandas as pd
import numpy as np

yname = getattr(y, "name", "y") or "y"

# 1) Collect the matrices
coef  = res.params
se    = res.bse
zval  = res.tvalues
pval  = res.pvalues
ci_lo = coef - 1.96 * se
ci_hi = coef + 1.96 * se

# 2) Determine the true outcome labels
# Statsmodels MNLogit drops one base category (usually the last in sorted order)
# The remaining fitted equations correspond to the other categories in sorted order
cats = pd.Series(y).dropna().unique()
cats = np.sort(cats)                       # ensure sorted numeric order
base = cats[-1]                            # last one = base category
nonbase = [c for c in cats if c != base]

# Now map each column of coef (in order) to its actual category label
if len(nonbase) != len(coef.columns):
    # fallback if categories somehow mismatched
    outcome_labels = [f"{yname}={c}" for c in coef.columns]
else:
    outcome_labels = [f"{yname}={c}" for c in nonbase]

outcome_map = {col: label for col, label in zip(coef.columns, outcome_labels)}

# 3) Stack for tidy alignment
def S(df, name):
    s = df.stack()
    s.name = name
    return s

stacked = pd.concat([
    S(coef,  "coef"),
    S(se,    "std err"),
    S(zval,  "z"),
    S(pval,  "P>|z|"),
    S(ci_lo, "[0.025"),
    S(ci_hi, "0.975]"),
], axis=1).reset_index().rename(columns={"level_0":"Variable", "level_1":"Outcome"})

# 4) Apply the proper outcome labels
stacked["Outcome"] = stacked["Outcome"].map(outcome_map)

# 5) Sort and export
stacked["Outcome"] = pd.Categorical(stacked["Outcome"], categories=outcome_labels, ordered=True)
stacked["Variable"] = pd.Categorical(stacked["Variable"], categories=list(coef.index), ordered=True)
coef_tidy = stacked.sort_values(["Outcome", "Variable"]).reset_index(drop=True)

out_path = "mnlogit_coefficients_tidy.xlsx"
with pd.ExcelWriter(out_path, engine="xlsxwriter") as xw:
    coef_tidy.to_excel(xw, sheet_name="Coefficients", index=False)

print(f"Exported → {out_path}")
# Out:
# Exported → mnlogit_coefficients_tidy.xlsx

# %% [markdown]
# Notes:
# - Preprocessing matches OLS: **winsorisation**, **z-scored predictors**, **Foreign**, **HGX Increased**, **sector** dummies, **INT×Size**.
# - Model step is swapped to **MNLogit**.
# - If the base is High Growth (3), the notebook also **derives High Growth vs Stressed** ORs automatically.
# - All predictors are coerced to float before fitting to avoid dtype errors.
