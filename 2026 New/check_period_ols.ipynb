# %% [markdown]
# # Period OLS Review
#
# Lightweight review notebook for `Results_period_ols.xlsx`. This notebook does not repeat the estimation pipeline.

# %%
from pathlib import Path

import pandas as pd

# %%
path = Path("Results_period_ols.xlsx")
summary = pd.read_excel(path, sheet_name="Model_Summary")
coeffs = pd.read_excel(path, sheet_name="Coefficients_All")
compare_baseline = pd.read_excel(path, sheet_name="Compare_Baseline")
compare_winsor = pd.read_excel(path, sheet_name="Compare_Winsor")
diagnostics = pd.read_excel(path, sheet_name="Diagnostics")

# %%
summary

# %%
coeffs.head(20)

# %%
compare_baseline

# %%
compare_winsor

# %%
diagnostics
