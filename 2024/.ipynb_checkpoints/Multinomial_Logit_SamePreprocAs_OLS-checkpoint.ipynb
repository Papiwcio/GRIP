# %% [markdown]
# # Multinomial Logit — **Same preprocessing as OLS**, modelling step swapped
# This notebook mirrors the OLS pipeline (winsorisation, standardisation, dummies, interaction),
# then fits a multinomial logit on `SGrowth_2`. It auto-detects the base category and derives
# `High Growth vs Stressed` if needed. Exports odds ratios and marginal effects to Excel.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy.stats.mstats import winsorize
from IPython.display import display

# %%
# === LOAD DATA ===
FILE = '2000 Analysis Python CHANGED.xlsx'
df = pd.read_excel(FILE)
print('Loaded:', df.shape)
# Out:
# Loaded: (9050, 82)

# %%
# === PARAMETERS (match OLS) ===
target_cont = 'LSGrowth_2023_2019'                 # continuous growth used in OLS
winsor_limits = (0.025, 0.025)                     # 2.5% tails as in OLS
core_cont = ['Starting_INT','Starting_BS_Strength','Starting_Size_ln','Starting_Profit']
cat_target = 'SGrowth_2'                           # categorical for MNLogit
sector_ref = 'budownictwo'                         # OLS reference sector
pf_col = 'P/F'                                     # ownership P/F
hgx_col = 'HGX'                                    # Increased/Decreased Export Intensity

# %%
# === WINSORISE CONTINUOUS DV (as in OLS) ===
if target_cont in df.columns:
    arr = df[target_cont].astype(float).to_numpy()
    df[target_cont + '_win'] = winsorize(arr, limits=winsor_limits)
    print('Winsorised DV created:', target_cont + '_win')
else:
    print('Warning: continuous OLS DV not found; continuing with multinomial anyway.')
# Out:
# Winsorised DV created: LSGrowth_2023_2019_win

# %%
# === STANDARDISE core continuous predictors (z-score), as in OLS ===
for c in core_cont:
    if c in df.columns:
        mu, sd = df[c].mean(), df[c].std(ddof=0)
        df[c + '_z'] = (df[c] - mu) / (sd if sd else 1.0)
    else:
        raise KeyError(f'Missing predictor: {c}')
print('Standardised predictors:', [c + '_z' for c in core_cont])
# Out:
# Standardised predictors: ['Starting_INT_z', 'Starting_BS_Strength_z', 'Starting_Size_ln_z', 'Starting_Profit_z']

# %%
# === DUMMIES to match OLS ===
# Foreign dummy from P/F (F=1, P=0)
df['Foreign'] = (df[pf_col].astype(str).str.upper().str.strip() == 'F').astype(int)

# HGX Increased Export Intensity dummy (reference = Decreased)
df['HGX_Increased Export Intensity'] = (df[hgx_col].astype(str).str.strip() == 'Increased Export Intensity').astype(int)

# Sector dummies, drop reference sector
sector_d = pd.get_dummies(df['Sector'], prefix='Sector', drop_first=False)
ref_col = f'Sector_{sector_ref}'
if ref_col in sector_d.columns:
    sector_d = sector_d.drop(columns=[ref_col])
print('Sector dummies:', len(sector_d.columns), ' (ref =', sector_ref, ')')
# Out:
# Sector dummies: 14  (ref = budownictwo )

# %%
# === INTERACTION (as in OLS) ===
df['Starting_INT_Mult_Starting_Size_ln'] = df['Starting_INT'] * df['Starting_Size_ln']

# Collect the design matrix columns mirroring OLS structure (z-scored cores + dummies + interaction)
X_cols = [c + '_z' for c in core_cont] + ['Foreign','HGX_Increased Export Intensity','Starting_INT_Mult_Starting_Size_ln']
X = pd.concat([df[X_cols], sector_d], axis=1)

# Align with categorical target
cat_map = {'0.Stressed':0,'1.Declining':1,'2.Stable':2,'3.High Growth':3}
y = df[cat_target].map(cat_map)
mask = (~y.isna()) & (~X.isna().any(axis=1))
X = X.loc[mask].copy()
y = y.loc[mask].astype(int)
print('Model N:', X.shape[0], 'Features:', X.shape[1])
# Out:
# Model N: 9015 Features: 21

# %%
# === SAFETY: ensure numeric dtypes to avoid object errors ===
Xc = sm.add_constant(X, has_constant='add')
Xc = Xc.astype(float)
y = y.astype(int)
print('dtypes:', Xc.dtypes.value_counts().to_dict())
# Out:
# dtypes: {dtype('float64'): 22}

# %%
# === FIT MULTINOMIAL LOGIT ===
mnl = sm.MNLogit(y, Xc).fit()
display(mnl.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 1.181488
#          Iterations: 35
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:              SGrowth_2   No. Observations:                 9015
# Model:                        MNLogit   Df Residuals:                     8949
# Method:                           MLE   Df Model:                           63
# Date:                Fri, 19 Sep 2025   Pseudo R-squ.:                 0.04775
# Time:                        14:33:49   Log-Likelihood:                -10651.
# converged:                      False   LL-Null:                       -11185.
# Covariance Type:            nonrobust   LLR p-value:                1.207e-182
# ======================================================================================================
#                        SGrowth_2=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.8154      0.531      1.536      0.125      -0.225       1.856
# Starting_INT_z                         0.2971      0.581      0.511      0.609      -0.842       1.437
# Starting_BS_Strength_z                 0.2931      0.038      7.735      0.000       0.219       0.367
# Starting_Size_ln_z                     0.1472      0.051      2.893      0.004       0.047       0.247
# Starting_Profit_z                      0.1082      0.040      2.721      0.007       0.030       0.186
# Foreign                               -0.0444      0.074     -0.603      0.547      -0.189       0.100
# HGX_Increased Export Intensity         0.0393      0.072      0.549      0.583      -0.101       0.179
# Starting_INT_Mult_Starting_Size_ln    -0.0007      0.001     -0.595      0.552      -0.003       0.002
# Sector_chemia                          0.4876      0.219      2.222      0.026       0.057       0.918
# Sector_energetyka                     -0.7708      0.364     -2.120      0.034      -1.483      -0.058
# Sector_górnictwo i hutnictwo           0.7978      0.269      2.962      0.003       0.270       1.326
# Sector_handel detaliczny               0.4278      0.191      2.245      0.025       0.054       0.801
# Sector_handel hurtowy                  0.0554      0.133      0.416      0.677      -0.206       0.316
# Sector_handle detaliczny             -16.0600   3.27e+06  -4.92e-06      1.000    -6.4e+06     6.4e+06
# Sector_media, telekomunkacja, IT       1.1407      0.181      6.292      0.000       0.785       1.496
# Sector_motoryzacja                     0.7466      0.137      5.435      0.000       0.477       1.016
# Sector_ochrona zdrowia i farmacja      0.9211      0.194      4.751      0.000       0.541       1.301
# Sector_paliwa                         -0.2539      0.187     -1.361      0.174      -0.620       0.112
# Sector_produkcja                       0.5951      0.124      4.801      0.000       0.352       0.838
# Sector_transport                       0.8149      0.182      4.485      0.000       0.459       1.171
# Sector_usługi                          0.9169      0.175      5.246      0.000       0.574       1.260
# Sector_żywność                         1.8215      0.214      8.518      0.000       1.402       2.241
# ------------------------------------------------------------------------------------------------------
#                        SGrowth_2=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  2.5320      0.540      4.686      0.000       1.473       3.591
# Starting_INT_z                         1.8591      0.594      3.131      0.002       0.695       3.023
# Starting_BS_Strength_z                 0.3303      0.038      8.621      0.000       0.255       0.405
# Starting_Size_ln_z                     0.3092      0.050      6.203      0.000       0.211       0.407
# Starting_Profit_z                      0.1923      0.040      4.812      0.000       0.114       0.271
# Foreign                               -0.2140      0.073     -2.912      0.004      -0.358      -0.070
# HGX_Increased Export Intensity         0.2762      0.071      3.876      0.000       0.137       0.416
# Starting_INT_Mult_Starting_Size_ln    -0.0043      0.001     -3.401      0.001      -0.007      -0.002
# Sector_chemia                          0.5466      0.211      2.591      0.010       0.133       0.960
# Sector_energetyka                     -1.2364      0.367     -3.372      0.001      -1.955      -0.518
# Sector_górnictwo i hutnictwo           0.4102      0.272      1.506      0.132      -0.124       0.944
# Sector_handel detaliczny              -0.0494      0.193     -0.256      0.798      -0.427       0.328
# Sector_handel hurtowy                  0.0181      0.128      0.141      0.888      -0.233       0.269
# Sector_handle detaliczny              14.6084   1978.936      0.007      0.994   -3864.034    3893.251
# Sector_media, telekomunkacja, IT       0.3904      0.187      2.087      0.037       0.024       0.757
# Sector_motoryzacja                     0.4359      0.136      3.196      0.001       0.169       0.703
# Sector_ochrona zdrowia i farmacja      0.7235      0.193      3.758      0.000       0.346       1.101
# Sector_paliwa                         -0.4683      0.182     -2.575      0.010      -0.825      -0.112
# Sector_produkcja                       0.2350      0.122      1.922      0.055      -0.005       0.474
# Sector_transport                       0.8382      0.177      4.740      0.000       0.492       1.185
# Sector_usługi                          0.3937      0.178      2.217      0.027       0.046       0.742
# Sector_żywność                         2.1198      0.209     10.133      0.000       1.710       2.530
# ------------------------------------------------------------------------------------------------------
#                        SGrowth_2=3       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  2.5884      0.740      3.499      0.000       1.138       4.038
# Starting_INT_z                         3.6863      0.815      4.522      0.000       2.088       5.284
# Starting_BS_Strength_z                 0.0674      0.046      1.456      0.145      -0.023       0.158
# Starting_Size_ln_z                     0.2944      0.059      4.980      0.000       0.179       0.410
# Starting_Profit_z                      0.1841      0.047      3.883      0.000       0.091       0.277
# Foreign                               -0.5162      0.097     -5.317      0.000      -0.707      -0.326
# HGX_Increased Export Intensity         0.3230      0.093      3.478      0.001       0.141       0.505
# Starting_INT_Mult_Starting_Size_ln    -0.0079      0.002     -4.537      0.000      -0.011      -0.004
# Sector_chemia                         -0.5683      0.383     -1.486      0.137      -1.318       0.181
# Sector_energetyka                      2.1552      0.295      7.312      0.000       1.577       2.733
# Sector_górnictwo i hutnictwo         -10.7222     69.970     -0.153      0.878    -147.862     126.417
# Sector_handel detaliczny               0.5725      0.246      2.329      0.020       0.091       1.054
# Sector_handel hurtowy                  0.2329      0.182      1.282      0.200      -0.123       0.589
# Sector_handle detaliczny             -15.3313   3.27e+06  -4.69e-06      1.000    -6.4e+06     6.4e+06
# Sector_media, telekomunkacja, IT       1.0371      0.232      4.469      0.000       0.582       1.492
# Sector_motoryzacja                     0.7009      0.185      3.780      0.000       0.338       1.064
# Sector_ochrona zdrowia i farmacja      0.8395      0.255      3.292      0.001       0.340       1.339
# Sector_paliwa                          0.3954      0.229      1.729      0.084      -0.053       0.844
# Sector_produkcja                       0.2395      0.175      1.368      0.171      -0.104       0.583
# Sector_transport                       0.3982      0.254      1.569      0.117      -0.099       0.896
# Sector_usługi                          1.0521      0.220      4.788      0.000       0.621       1.483
# Sector_żywność                         2.0237      0.246      8.213      0.000       1.541       2.507
# ======================================================================================================
# """

# %%
# === BUILD ODDS RATIOS per reported category vs base ===
params = mnl.params
pvals  = mnl.pvalues
bse    = mnl.bse
or_tables = {}
if isinstance(params, pd.DataFrame):
    cats = params.columns.tolist()  # non-base cats
    print('Non-base categories (columns):', cats)
    for k in cats:
        beta  = params[k]
        se    = bse[k]
        lower = beta - 1.96*se
        upper = beta + 1.96*se
        out = pd.DataFrame({
            'Odds Ratio': np.exp(beta),
            'CI Lower':   np.exp(lower),
            'CI Upper':   np.exp(upper),
            'p-value':    pvals[k]
        })
        or_tables[k] = out
else:
    # MultiIndex on rows: (cat, predictor)
    cats = params.index.get_level_values(0).unique().tolist()
    print('Non-base categories (index):', cats)
    for k in cats:
        beta  = params.loc[k]
        se    = bse.loc[k]
        lower = beta - 1.96*se
        upper = beta + 1.96*se
        out = pd.DataFrame({
            'Odds Ratio': np.exp(beta),
            'CI Lower':   np.exp(lower),
            'CI Upper':   np.exp(upper),
            'p-value':    pvals.loc[k]
        })
        or_tables[k] = out

for k in or_tables:
    print(f"\n### ORs — Category {k} vs base")
    display(or_tables[k].sort_values('p-value').head(25))
# Out:
# Non-base categories (columns): [0, 1, 2]
#
# ### ORs — Category 0 vs base
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                                       Odds Ratio  CI Lower  CI Upper  \
# Sector_żywność                      6.181256e+00  4.064939  9.399385
# Starting_BS_Strength_z              1.340569e+00  1.244616  1.443921
# Sector_media, telekomunkacja, IT    3.129080e+00  2.193300  4.464114
# Sector_motoryzacja                  2.109863e+00  1.611799  2.761834
# Sector_usługi                       2.501645e+00  1.776016  3.523745
# Sector_produkcja                    1.813147e+00  1.422088  2.311742
# Sector_ochrona zdrowia i farmacja   2.512173e+00  1.717955  3.673561
# Sector_transport                    2.258851e+00  1.582144  3.224995
# Sector_górnictwo i hutnictwo        2.220593e+00  1.309705  3.764994
# Starting_Size_ln_z                  1.158611e+00  1.048627  1.280131
# Starting_Profit_z                   1.114271e+00  1.030724  1.204590
# Sector_handel detaliczny            1.533806e+00  1.055795  2.228237
# Sector_chemia                       1.628358e+00  1.059104  2.503577
# Sector_energetyka                   4.626214e-01  0.226862  0.943385
# const                               2.259970e+00  0.798364  6.397413
# Sector_paliwa                       7.757405e-01  0.538106  1.118318
# Foreign                             9.565723e-01  0.827990  1.105122
# Starting_INT_Mult_Starting_Size_ln  9.992677e-01  0.996860  1.001681
# HGX_Increased Export Intensity      1.040057e+00  0.904019  1.196566
# Starting_INT_z                      1.345895e+00  0.430673  4.206047
# Sector_handel hurtowy               1.056986e+00  0.814117  1.372310
# Sector_handle detaliczny            1.059844e-07  0.000000       inf
#
#                                          p-value
# Sector_żywność                      1.620155e-17
# Starting_BS_Strength_z              1.033449e-14
# Sector_media, telekomunkacja, IT    3.128230e-10
# Sector_motoryzacja                  5.492584e-08
# Sector_usługi                       1.552757e-07
# Sector_produkcja                    1.579312e-06
# Sector_ochrona zdrowia i farmacja   2.023936e-06
# Sector_transport                    7.279777e-06
# Sector_górnictwo i hutnictwo        3.060548e-03
# Starting_Size_ln_z                  3.815123e-03
# Starting_Profit_z                   6.508355e-03
# Sector_handel detaliczny            2.477158e-02
# Sector_chemia                       2.630668e-02
# Sector_energetyka                   3.398006e-02
# const                               1.245817e-01
# Sector_paliwa                       1.735887e-01
# Foreign                             5.466200e-01
# Starting_INT_Mult_Starting_Size_ln  5.517775e-01
# HGX_Increased Export Intensity      5.829040e-01
# Starting_INT_z                      6.093700e-01
# Sector_handel hurtowy               6.773535e-01
# Sector_handle detaliczny            9.999961e-01
# ### ORs — Category 1 vs base
#                                       Odds Ratio  CI Lower   CI Upper  \
# Sector_żywność                      8.329126e+00  5.527442  12.550896
# Starting_BS_Strength_z              1.391353e+00  1.290700   1.499854
# Starting_Size_ln_z                  1.362282e+00  1.235496   1.502078
# Starting_Profit_z                   1.212013e+00  1.120702   1.310764
# Sector_transport                    2.312090e+00  1.634879   3.269820
# const                               1.257877e+01  4.361857  36.274761
# HGX_Increased Export Intensity      1.318152e+00  1.146321   1.515741
# Sector_ochrona zdrowia i farmacja   2.061549e+00  1.413602   3.006493
# Starting_INT_Mult_Starting_Size_ln  9.957316e-01  0.993280   0.998189
# Sector_energetyka                   2.904190e-01  0.141534   0.595922
# Sector_motoryzacja                  1.546338e+00  1.183662   2.020138
# Starting_INT_z                      6.417714e+00  2.003953  20.552906
# Foreign                             8.073565e-01  0.699046   0.932448
# Sector_chemia                       1.727339e+00  1.142329   2.611944
# Sector_paliwa                       6.260774e-01  0.438330   0.894241
# Sector_usługi                       1.482519e+00  1.046655   2.099891
# Sector_media, telekomunkacja, IT    1.477586e+00  1.023967   2.132160
# Sector_produkcja                    1.264847e+00  0.995415   1.607207
# Sector_górnictwo i hutnictwo        1.507107e+00  0.883586   2.570629
# Sector_handel detaliczny            9.518233e-01  0.652403   1.388662
# Sector_handel hurtowy               1.018221e+00  0.791933   1.309170
# Sector_handle detaliczny            2.209723e+06  0.000000        inf
#
#                                          p-value
# Sector_żywność                      3.957660e-24
# Starting_BS_Strength_z              6.654524e-18
# Starting_Size_ln_z                  5.541471e-10
# Starting_Profit_z                   1.497951e-06
# Sector_transport                    2.137977e-06
# const                               2.789299e-06
# HGX_Increased Export Intensity      1.060701e-04
# Sector_ochrona zdrowia i farmacja   1.712396e-04
# Starting_INT_Mult_Starting_Size_ln  6.717940e-04
# Sector_energetyka                   7.475164e-04
# Sector_motoryzacja                  1.391148e-03
# Starting_INT_z                      1.744853e-03
# Foreign                             3.595087e-03
# Sector_chemia                       9.577222e-03
# Sector_paliwa                       1.003704e-02
# Sector_usługi                       2.664230e-02
# Sector_media, telekomunkacja, IT    3.692606e-02
# Sector_produkcja                    5.455545e-02
# Sector_górnictwo i hutnictwo        1.321471e-01
# Sector_handel detaliczny            7.977848e-01
# Sector_handel hurtowy               8.880143e-01
# Sector_handle detaliczny            9.941101e-01
# ### ORs — Category 2 vs base
#                                       Odds Ratio      CI Lower      CI Upper  \
# Sector_żywność                      7.566505e+00  4.668205e+00  1.226424e+01
# Sector_energetyka                   8.629531e+00  4.842631e+00  1.537776e+01
# Foreign                             5.967600e-01  4.933496e-01  7.218462e-01
# Starting_Size_ln_z                  1.342387e+00  1.195507e+00  1.507313e+00
# Sector_usługi                       2.863661e+00  1.861519e+00  4.405301e+00
# Starting_INT_Mult_Starting_Size_ln  9.921678e-01  9.888030e-01  9.955440e-01
# Starting_INT_z                      3.989728e+01  8.071844e+00  1.972031e+02
# Sector_media, telekomunkacja, IT    2.820995e+00  1.790092e+00  4.445589e+00
# Starting_Profit_z                   1.202139e+00  1.095463e+00  1.319203e+00
# Sector_motoryzacja                  2.015647e+00  1.401445e+00  2.899029e+00
# const                               1.330892e+01  3.121798e+00  5.673885e+01
# HGX_Increased Export Intensity      1.381241e+00  1.151405e+00  1.656954e+00
# Sector_ochrona zdrowia i farmacja   2.315209e+00  1.404391e+00  3.816740e+00
# Sector_handel detaliczny            1.772712e+00  1.094933e+00  2.870046e+00
# Sector_paliwa                       1.485003e+00  9.485225e-01  2.324916e+00
# Sector_transport                    1.489168e+00  9.053895e-01  2.449357e+00
# Sector_chemia                       5.664781e-01  2.676418e-01  1.198981e+00
# Starting_BS_Strength_z              1.069748e+00  9.769607e-01  1.171348e+00
# Sector_produkcja                    1.270632e+00  9.015945e-01  1.790721e+00
# Sector_handel hurtowy               1.262241e+00  8.841913e-01  1.801933e+00
# Sector_górnictwo i hutnictwo        2.204894e-05  6.073158e-65  8.004992e+54
# Sector_handle detaliczny            2.196289e-07  0.000000e+00           inf
#
#                                          p-value
# Sector_żywność                      2.157613e-16
# Sector_energetyka                   2.638892e-13
# Foreign                             1.054269e-07
# Starting_Size_ln_z                  6.346633e-07
# Sector_usługi                       1.686685e-06
# Starting_INT_Mult_Starting_Size_ln  5.715132e-06
# Starting_INT_z                      6.137740e-06
# Sector_media, telekomunkacja, IT    7.851106e-06
# Starting_Profit_z                   1.031269e-04
# Sector_motoryzacja                  1.567343e-04
# const                               4.673770e-04
# HGX_Increased Export Intensity      5.046229e-04
# Sector_ochrona zdrowia i farmacja   9.964668e-04
# Sector_handel detaliczny            1.986260e-02
# Sector_paliwa                       8.382345e-02
# Sector_transport                    1.167603e-01
# Sector_chemia                       1.373799e-01
# Starting_BS_Strength_z              1.452596e-01
# Sector_produkcja                    1.712384e-01
# Sector_handel hurtowy               1.997364e-01
# Sector_górnictwo i hutnictwo        8.782092e-01
# Sector_handle detaliczny            9.999963e-01

# %%
# === DERIVE High Growth (3) vs Stressed (0) when base is 3 ===
derived_hg_vs_0 = None
if isinstance(params, pd.DataFrame) and (0 in params.columns.tolist()) and (3 not in params.columns.tolist()):
    beta = -params[0]          # negate Stressed vs HG
    se   =  bse[0]
    lower = beta - 1.96*se
    upper = beta + 1.96*se
    derived_hg_vs_0 = pd.DataFrame({
        'Odds Ratio': np.exp(beta),
        'CI Lower':   np.exp(lower),
        'CI Upper':   np.exp(upper),
        'p-value (from Stressed vs HG)': pvals[0]
    })
    print('\n### Derived — High Growth (3) vs Stressed (0)')
    display(derived_hg_vs_0.sort_values('p-value (from Stressed vs HG)').head(25))
# Out:
# ### Derived — High Growth (3) vs Stressed (0)
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                                       Odds Ratio  CI Lower  CI Upper  \
# Sector_żywność                      1.617794e-01  0.106390  0.246006
# Starting_BS_Strength_z              7.459517e-01  0.692559  0.803461
# Sector_media, telekomunkacja, IT    3.195827e-01  0.224009  0.455934
# Sector_motoryzacja                  4.739645e-01  0.362078  0.620425
# Sector_usługi                       3.997370e-01  0.283789  0.563058
# Sector_produkcja                    5.515274e-01  0.432574  0.703191
# Sector_ochrona zdrowia i farmacja   3.980617e-01  0.272215  0.582087
# Sector_transport                    4.427029e-01  0.310078  0.632054
# Sector_górnictwo i hutnictwo        4.503303e-01  0.265605  0.763531
# Starting_Size_ln_z                  8.631023e-01  0.781170  0.953628
# Starting_Profit_z                   8.974478e-01  0.830158  0.970192
# Sector_handel detaliczny            6.519729e-01  0.448785  0.947154
# Sector_chemia                       6.141156e-01  0.399428  0.944194
# Sector_energetyka                   2.161595e+00  1.060012  4.407959
# const                               4.424837e-01  0.156313  1.252561
# Sector_paliwa                       1.289091e+00  0.894200  1.858371
# Foreign                             1.045399e+00  0.904877  1.207744
# Starting_INT_Mult_Starting_Size_ln  1.000733e+00  0.998321  1.003150
# HGX_Increased Export Intensity      9.614859e-01  0.835725  1.106171
# Starting_INT_z                      7.430003e-01  0.237753  2.321946
# Sector_handel hurtowy               9.460860e-01  0.728698  1.228325
# Sector_handle detaliczny            9.435353e+06  0.000000       inf
#
#                                     p-value (from Stressed vs HG)
# Sector_żywność                                       1.620155e-17
# Starting_BS_Strength_z                               1.033449e-14
# Sector_media, telekomunkacja, IT                     3.128230e-10
# Sector_motoryzacja                                   5.492584e-08
# Sector_usługi                                        1.552757e-07
# Sector_produkcja                                     1.579312e-06
# Sector_ochrona zdrowia i farmacja                    2.023936e-06
# Sector_transport                                     7.279777e-06
# Sector_górnictwo i hutnictwo                         3.060548e-03
# Starting_Size_ln_z                                   3.815123e-03
# Starting_Profit_z                                    6.508355e-03
# Sector_handel detaliczny                             2.477158e-02
# Sector_chemia                                        2.630668e-02
# Sector_energetyka                                    3.398006e-02
# const                                                1.245817e-01
# Sector_paliwa                                        1.735887e-01
# Foreign                                              5.466200e-01
# Starting_INT_Mult_Starting_Size_ln                   5.517775e-01
# HGX_Increased Export Intensity                       5.829040e-01
# Starting_INT_z                                       6.093700e-01
# Sector_handel hurtowy                                6.773535e-01
# Sector_handle detaliczny                             9.999961e-01

# %%
# === MARGINAL EFFECTS (average dydx) ===
mfx = mnl.get_margeff(at='overall', method='dydx').summary_frame()
display(mfx.head(40))
# Out:
#                                                    dy/dx      Std. Err.  \
# endog       exog
# SGrowth_2=0 Starting_INT_z                     -0.157573       0.060898
#             Starting_BS_Strength_z             -0.031416       0.003828
#             Starting_Size_ln_z                 -0.026458       0.005227
#             Starting_Profit_z                  -0.017290       0.004079
#             Foreign                             0.019959       0.007601
#             HGX_Increased Export Intensity     -0.019950       0.007386
#             Starting_INT_Mult_Starting_Size_ln  0.000356       0.000129
#             Sector_chemia                      -0.042366       0.022605
#             Sector_energetyka                   0.066993       0.033021
#             Sector_górnictwo i hutnictwo        0.094568       1.003852
#             Sector_handel detaliczny           -0.026906       0.019402
#             Sector_handel hurtowy              -0.006947       0.013082
#             Sector_handle detaliczny            0.303905  167719.279177
#             Sector_media, telekomunkacja, IT   -0.090024       0.019090
#             Sector_motoryzacja                 -0.067977       0.013967
#             Sector_ochrona zdrowia i farmacja  -0.092499       0.020145
#             Sector_paliwa                       0.029534       0.018060
#             Sector_produkcja                   -0.044153       0.012571
#             Sector_transport                   -0.086487       0.018673
#             Sector_usługi                      -0.079368       0.018120
#             Sector_żywność                     -0.221513       0.022985
# SGrowth_2=1 Starting_INT_z                     -0.326564       0.084659
#             Starting_BS_Strength_z              0.017061       0.005866
#             Starting_Size_ln_z                 -0.020963       0.007108
#             Starting_Profit_z                  -0.009300       0.005855
#             Foreign                             0.038496       0.010743
#             HGX_Increased Export Intensity     -0.041751       0.010369
#             Starting_INT_Mult_Starting_Size_ln  0.000719       0.000179
#             Sector_chemia                       0.052630       0.033590
#             Sector_energetyka                  -0.074220       0.071900
#             Sector_górnictwo i hutnictwo        0.498175       2.451949
#             Sector_handel detaliczny            0.083966       0.030387
#             Sector_handel hurtowy               0.001835       0.022731
#             Sector_handle detaliczny           -5.184926  749521.599575
#             Sector_media, telekomunkacja, IT    0.166728       0.025416
#             Sector_motoryzacja                  0.082662       0.021484
#             Sector_ochrona zdrowia i farmacja   0.076427       0.027632
#             Sector_paliwa                      -0.004745       0.032903
#             Sector_produkcja                    0.093080       0.019532
#             Sector_transport                    0.051452       0.026626
#
#                                                        z      Pr(>|z|)  \
# endog       exog
# SGrowth_2=0 Starting_INT_z                     -2.587480  9.668085e-03
#             Starting_BS_Strength_z             -8.206904  2.269656e-16
#             Starting_Size_ln_z                 -5.062119  4.146215e-07
#             Starting_Profit_z                  -4.238364  2.251550e-05
#             Foreign                             2.625859  8.643060e-03
#             HGX_Increased Export Intensity     -2.700985  6.913451e-03
#             Starting_INT_Mult_Starting_Size_ln  2.759873  5.782384e-03
#             Sector_chemia                      -1.874189  6.090437e-02
#             Sector_energetyka                   2.028810  4.247765e-02
#             Sector_górnictwo i hutnictwo        0.094205  9.249459e-01
#             Sector_handel detaliczny           -1.386800  1.655027e-01
#             Sector_handel hurtowy              -0.531041  5.953902e-01
#             Sector_handle detaliczny            0.000002  9.999986e-01
#             Sector_media, telekomunkacja, IT   -4.715641  2.409509e-06
#             Sector_motoryzacja                 -4.867081  1.132585e-06
#             Sector_ochrona zdrowia i farmacja  -4.591664  4.397263e-06
#             Sector_paliwa                       1.635283  1.019898e-01
#             Sector_produkcja                   -3.512203  4.444086e-04
#             Sector_transport                   -4.631649  3.627641e-06
#             Sector_usługi                      -4.380007  1.186757e-05
#             Sector_żywność                     -9.637412  5.557147e-22
# SGrowth_2=1 Starting_INT_z                     -3.857412  1.145938e-04
#             Starting_BS_Strength_z              2.908253  3.634545e-03
#             Starting_Size_ln_z                 -2.949292  3.185033e-03
#             Starting_Profit_z                  -1.588285  1.122219e-01
#             Foreign                             3.583548  3.389587e-04
#             HGX_Increased Export Intensity     -4.026566  5.659744e-05
#             Starting_INT_Mult_Starting_Size_ln  4.018107  5.866764e-05
#             Sector_chemia                       1.566834  1.171534e-01
#             Sector_energetyka                  -1.032269  3.019461e-01
#             Sector_górnictwo i hutnictwo        0.203175  8.389983e-01
#             Sector_handel detaliczny            2.763261  5.722702e-03
#             Sector_handel hurtowy               0.080739  9.356496e-01
#             Sector_handle detaliczny           -0.000007  9.999945e-01
#             Sector_media, telekomunkacja, IT    6.560059  5.378649e-11
#             Sector_motoryzacja                  3.847638  1.192622e-04
#             Sector_ochrona zdrowia i farmacja   2.765841  5.677613e-03
#             Sector_paliwa                      -0.144224  8.853240e-01
#             Sector_produkcja                    4.765458  1.884248e-06
#             Sector_transport                    1.932398  5.331045e-02
#
#                                                 Conf. Int. Low  Cont. Int. Hi.
# endog       exog
# SGrowth_2=0 Starting_INT_z                       -2.769310e-01   -3.821457e-02
#             Starting_BS_Strength_z               -3.891921e-02   -2.391356e-02
#             Starting_Size_ln_z                   -3.670198e-02   -1.621388e-02
#             Starting_Profit_z                    -2.528478e-02   -9.294255e-03
#             Foreign                               5.061438e-03    3.485663e-02
#             HGX_Increased Export Intensity       -3.442696e-02   -5.473369e-03
#             Starting_INT_Mult_Starting_Size_ln    1.032111e-04    6.089938e-04
#             Sector_chemia                        -8.667007e-02    1.938920e-03
#             Sector_energetyka                     2.273343e-03    1.317122e-01
#             Sector_górnictwo i hutnictwo         -1.872944e+00    2.062081e+00
#             Sector_handel detaliczny             -6.493258e-02    1.112029e-02
#             Sector_handel hurtowy                -3.258656e-02    1.869272e-02
#             Sector_handle detaliczny             -3.287234e+05    3.287241e+05
#             Sector_media, telekomunkacja, IT     -1.274401e-01   -5.260704e-02
#             Sector_motoryzacja                   -9.535064e-02   -4.060255e-02
#             Sector_ochrona zdrowia i farmacja    -1.319822e-01   -5.301546e-02
#             Sector_paliwa                        -5.863890e-03    6.493179e-02
#             Sector_produkcja                     -6.879244e-02   -1.951372e-02
#             Sector_transport                     -1.230850e-01   -4.988829e-02
#             Sector_usługi                        -1.148831e-01   -4.385226e-02
#             Sector_żywność                       -2.665624e-01   -1.764640e-01
# SGrowth_2=1 Starting_INT_z                       -4.924928e-01   -1.606359e-01
#             Starting_BS_Strength_z                5.563104e-03    2.855923e-02
#             Starting_Size_ln_z                   -3.489484e-02   -7.032110e-03
#             Starting_Profit_z                    -2.077634e-02    2.176320e-03
#             Foreign                               1.744139e-02    5.955132e-02
#             HGX_Increased Export Intensity       -6.207322e-02   -2.142821e-02
#             Starting_INT_Mult_Starting_Size_ln    3.680782e-04    1.069118e-03
#             Sector_chemia                        -1.320520e-02    1.184650e-01
#             Sector_energetyka                    -2.151412e-01    6.670117e-02
#             Sector_górnictwo i hutnictwo         -4.307558e+00    5.303907e+00
#             Sector_handel detaliczny              2.440946e-02    1.435227e-01
#             Sector_handel hurtowy                -4.271684e-02    4.638741e-02
#             Sector_handle detaliczny             -1.469041e+06    1.469030e+06
#             Sector_media, telekomunkacja, IT      1.169140e-01    2.165412e-01
#             Sector_motoryzacja                    4.055430e-02    1.247690e-01
#             Sector_ochrona zdrowia i farmacja     2.226827e-02    1.305850e-01
#             Sector_paliwa                        -6.923468e-02    5.974383e-02
#             Sector_produkcja                      5.479737e-02    1.313620e-01
#             Sector_transport                     -7.339863e-04    1.036387e-01

# %%
# === EXPORT to Excel ===
with pd.ExcelWriter('MNLogit_SamePreprocAs_OLS.xlsx') as w:
    for k in or_tables:
        or_tables[k].to_excel(w, sheet_name=f'OR_cat{k}_vs_base')
    if derived_hg_vs_0 is not None:
        derived_hg_vs_0.to_excel(w, sheet_name='3_vs_0_Derived')
    mfx.to_excel(w, sheet_name='MarginalEffects_overall')
print('✅ Exported MNLogit_SamePreprocAs_OLS.xlsx')
# Out:
# ✅ Exported MNLogit_SamePreprocAs_OLS.xlsx

# %% [markdown]
# Notes:
# - Preprocessing matches OLS: **winsorisation**, **z-scored predictors**, **Foreign**, **HGX Increased**, **sector** dummies, **INT×Size**.
# - Model step is swapped to **MNLogit**.
# - If the base is High Growth (3), the notebook also **derives High Growth vs Stressed** ORs automatically.
# - All predictors are coerced to float before fitting to avoid dtype errors.
